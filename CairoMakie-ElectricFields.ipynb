# %%
using CairoMakie

f(x) = Point2f(
    (x[1] - 1)/((x[1] - 1)^2 + x[2]^2)^1.5 + (x[1]+1)/((x[1] + 1)^2 + x[2]^2)^1.5,
    x[2]/((x[1] - 1)^2 + x[2]^2)^1.5 + x[2]/((x[1] + 1)^2 + x[2]^2)^1.5
)

E(x) = f(x)

flows = streamplot(E, -1.5..1.5, -1.5..1.5, colormap = :magma)
# Out:
# FigureAxisPlot()
